# %%
# !pip install transformers
# !pip install datasets
# !pip install wandb
# !pip install python-dotenv

# %%
# !nvidia-smi

# %%
# %pwd
# Out:
# '/workspace/KLUE_NLI'

# %% [markdown]
# # Train & Inference

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["NCCL_P2P_DISABLE"]="1"
os.environ["NCCL_IB_DISABLE"]="1"
os.environ['WANDB_DISABLED'] = 'true'

# model 1 : valid_rtt + Roberta-Large
# !python train.py \
--data_name train_data.csv \
--valid_rtt False \
--k_fold 0 \
--run_name Roberta_Large_Triple_all \
--save_path output/model/Roberta_Large_Triple_all \
--model_name_or_path klue/roberta-large \
--train_dataset_path 'fake_triple/train_dataset_special.csv' \
--valid_dataset_path 'fake_triple/valid_dataset_special.csv' \
--test_dataset_path 'fake_triple/test_dataset_special.csv' \
--num_labels 2 \
--do_train \
--do_eval \
--output_dir output/log/Roberta_Large_Triple_all \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy epoch \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 8 \
--per_device_eval_batch_size 16 \
--gradient_accumulation_steps 1 \
--evaluation_strategy epoch \
--logging_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_rdrop False
# Out:
# 2024-05-02 05:51:09.691306: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-02 05:51:10.449486: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# #### Train dataset length : 586707 ####
# #### Validation dataset length : 18210 ####
# ----------------------------------------------------------------------------------------------------
# #### Example of train dataset : ('위장도급 판정나자 도급해지, 막무가내 동양시멘트', '정종환 국토해양부 장관이 4대강 공사 현장의 인명 사고를 개인의 실수로 돌리는 언급을 해 입방아에 올랐다.') ####
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["NCCL_P2P_DISABLE"]="1"
os.environ["NCCL_IB_DISABLE"]="1"
os.environ['WANDB_DISABLED'] = 'true'

# model 4 : Aeda data + Self-Explainable
# !python train.py \
--data_name train_data.csv \
--aeda False \
--k_fold 0 \
--run_name Explainable_small_01_all  \
--save_path output/model/Explainable_small_01_all  \
--model_name_or_path klue/roberta-small \
--train_dataset_path 'fake_all/train_dataset_special_01.csv' \
--valid_dataset_path 'fake_all/valid_dataset_special_01.xlsx' \
--test_dataset_path 'fake_all/test_dataset_special_01.xlsx' \
--do_train \
--do_eval \
--output_dir output/log/Explainable_small_01_all \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy epoch \
--num_train_epochs 3 \
--learning_rate 5e-5 \
--per_device_train_batch_size 4 \
--per_device_eval_batch_size 8 \
--gradient_accumulation_steps 2 \
--evaluation_strategy epoch \
--logging_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--label_smoothing_factor 0.1 \
--warmup_ratio 0.1 \
--weight_decay 1e-2 \
--use_SIC True
# Out:
# 2024-05-01 16:11:09.314674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 16:11:10.023362: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# #### Train dataset length : 296024 ####
# #### Validation dataset length : 36660 ####
# ----------------------------------------------------------------------------------------------------
# #### Example of train dataset : ('LGU+, 고객 500명과 화담숲 동감 트래킹 행사', 'LG유플러스가 멤버십 고객을 초청해 경기 광주 곤지암 화담숲에서 동감 트래킹 행사를 연다고 17일 밝혔다.') ####
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["NCCL_P2P_DISABLE"]="0"
os.environ["NCCL_IB_DISABLE"]="0"
os.environ['WANDB_DISABLED'] = 'true'

# !python inference.py \
--output_dir output/log/Roberta_Large_rdrop \
--overwrite_output_dir True \
--k_fold 0 \
--model_name_or_path klue/roberta-large \
--save_path output/model/Roberta_Large_rdrop  \
--output_name Roberta_Large_rdrop.csv \
--per_device_eval_batch_size 32 \
--do_predict True

# %%
# model 2 : valid_rtt + Roberta-LSTM + R-drop
# !python train.py \
--data_name train_data.csv \
--valid_rtt True \
--k_fold 5 \
--run_name Roberta_LSTM_rdrop \
--save_path ./checkpoints/Roberta_LSTM_rdrop \
--model_name_or_path klue/roberta-large \
--do_train \
--do_eval \
--output_dir /content/results \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy steps \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 16 \
--per_device_eval_batch_size 32 \
--gradient_accumulation_steps 2 \
--evaluation_strategy steps \
--logging_steps 100 \
--eval_steps 500 \
--save_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_lstm True \
--use_rdrop True

# %%
# !python inference.py \
--output_dir ./checkpoints \
--overwrite_output_dir True \
--k_fold 5 \
--model_name_or_path klue/roberta-large \
--save_path ./checkpoints/Roberta_LSTM_rdrop \
--output_name Roberta_LSTM_rdrop.csv \
--per_device_eval_batch_size 32 \
--do_predict True \
--use_lstm True

# %%
# model 3 : valid_rtt + Self-Explainable + R-drop
# !python train.py \
--data_name train_data.csv \
--aeda True \
--valid_rtt True \
--k_fold 5 \
--run_name Explainable_3ep_rdrop \
--save_path ./checkpoints/Explainable_3ep_rdrop \
--model_name_or_path klue/roberta-large \
--do_train \
--do_eval \
--output_dir /content/results \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy steps \
--num_train_epochs 3 \
--learning_rate 1e-5 \
--per_device_train_batch_size 10 \
--per_device_eval_batch_size 32 \
--gradient_accumulation_steps 1 \
--evaluation_strategy steps \
--logging_steps 100 \
--eval_steps 500 \
--save_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_SIC True \
--use_rdrop True

# %%
# !python inference.py \
--output_dir ./checkpoints \
--overwrite_output_dir True \
--k_fold 5 \
--model_name_or_path klue/roberta-large \
--save_path ./checkpoints/Explainable_3ep_rdrop \
--output_name Explainable_3ep_rdrop.csv \
--per_device_eval_batch_size 32 \
--do_predict True \
--use_SIC True

# %%
# model 4 : Aeda data + Self-Explainable
# !python train.py \
--data_name train_data.csv \
--aeda False \
--k_fold 0 \
--run_name Explainable_aeda  \
--save_path output/model/Explainable  \
--model_name_or_path klue/roberta-large \
--do_train \
--do_eval \
--output_dir output/log/Explainable \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy steps \
--num_train_epochs 3 \
--learning_rate 5e-5 \
--per_device_train_batch_size 4 \
--per_device_eval_batch_size 8 \
--gradient_accumulation_steps 2 \
--evaluation_strategy steps \
--logging_steps 100 \
--eval_steps 500 \
--save_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--label_smoothing_factor 0.1 \
--warmup_ratio 0.1 \
--weight_decay 1e-2 \
--use_SIC True

# %%
# !python inference.py \
--output_dir ./checkpoints \
--overwrite_output_dir True \
--k_fold 5 \
--model_name_or_path klue/roberta-large \
--save_path ./checkpoints/Explainable_aeda \
--output_name Explainable_aeda.csv \
--per_device_eval_batch_size 32 \
--do_predict True \
--use_SIC True
