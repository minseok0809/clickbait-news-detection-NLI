# %%
# !pip install transformers
# !pip install datasets
# !pip install wandb
# !pip install python-dotenv

# %%
# !nvidia-smi

# %%
# %pwd
# Out:
# '/workspace/KLUE_NLI'

# %% [markdown]
# # Train & Inference

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["NCCL_P2P_DISABLE"]="0"
os.environ["NCCL_IB_DISABLE"]="0"
os.environ['WANDB_DISABLED'] = 'true'

# model 2 : valid_rtt + Roberta-LSTM + R-drop
# !python train.py \
--data_name train_data.csv \
--valid_rtt False \
--k_fold 5 \
--run_name Roberta_LSTM_Small_00_all \
--save_path output/model/Roberta_LSTM_Small_00_all \
--model_name_or_path klue/roberta-small \
--train_dataset_path 'fake_all/train_dataset_not_special.csv' \
--valid_dataset_path 'fake_all/valid_dataset_not_special.xlsx' \
--test_dataset_path 'fake_all/test_dataset_not_special.xlsx' \
--do_train \
--do_eval \
--output_dir output/log/Roberta_LSTM_Small_00_all \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy epoch \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 32 \
--per_device_eval_batch_size 128 \
--gradient_accumulation_steps 2 \
--evaluation_strategy epoch \
--logging_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_lstm True \
--use_rdrop False
# Out:
# 2024-05-01 21:34:11.825717: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 21:34:12.496990: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# #### Total dataset length : 332684 ####
# ----------------------------------------------------------------------------------------------------
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["NCCL_P2P_DISABLE"]="0"
os.environ["NCCL_IB_DISABLE"]="0"
os.environ['WANDB_DISABLED'] = 'true'

# model 2 : valid_rtt + Roberta-LSTM + R-drop
# !python train.py \
--data_name train_data.csv \
--valid_rtt False \
--k_fold 0 \
--run_name Roberta_LSTM_Base_00_all \
--save_path output/model/Roberta_LSTM_Base_00_all \
--model_name_or_path klue/roberta-base \
--train_dataset_path 'fake_all/train_dataset_not_special.csv' \
--valid_dataset_path 'fake_all/valid_dataset_not_special.xlsx' \
--test_dataset_path 'fake_all/test_dataset_not_special.xlsx' \
--do_train \
--do_eval \
--output_dir output/log/Roberta_LSTM_Base_00_all \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy epoch \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 16 \
--per_device_eval_batch_size 64 \
--gradient_accumulation_steps 2 \
--evaluation_strategy epoch \
--logging_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_lstm True \
--use_rdrop False
# Out:
# 2024-05-01 19:16:51.141701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 19:16:51.818983: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# #### Train dataset length : 296024 ####
# #### Validation dataset length : 36660 ####
# ----------------------------------------------------------------------------------------------------
# ...

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"
os.environ["NCCL_P2P_DISABLE"]="0"
os.environ["NCCL_IB_DISABLE"]="0"
os.environ['WANDB_DISABLED'] = 'true'

# model 2 : valid_rtt + Roberta-LSTM + R-drop
# !python train.py \
--data_name train_data.csv \
--valid_rtt False \
--k_fold 0 \
--run_name Roberta_LSTM_Large_00_all \
--save_path output/model/Roberta_LSTM_Large_00_all \
--model_name_or_path klue/roberta-large \
--train_dataset_path 'fake_all/train_dataset_not_special.csv' \
--valid_dataset_path 'fake_all/valid_dataset_not_special.xlsx' \
--test_dataset_path 'fake_all/test_dataset_not_special.xlsx' \
--do_train \
--do_eval \
--output_dir output/log/Roberta_LSTM_Large_00_all \
--overwrite_output_dir True \
--save_total_limit 5 \
--save_strategy epoch \
--num_train_epochs 3 \
--learning_rate 3e-5 \
--per_device_train_batch_size 8 \
--per_device_eval_batch_size 32 \
--gradient_accumulation_steps 2 \
--evaluation_strategy epoch \
--logging_steps 500 \
--fp16 True \
--load_best_model_at_end True \
--metric_for_best_model accuracy \
--warmup_ratio 0.1 \
--weight_decay 1e-3 \
--use_lstm True \
--use_rdrop False
